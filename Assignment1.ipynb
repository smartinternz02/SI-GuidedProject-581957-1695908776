# %%
import pandas as pd
import numpy as np

# %%
# Task 1
data=np.random.rand(4,4) #random numers from [0,1) shape is 4x4
df=pd.DataFrame(data)
df
# Out:
#           0         1         2         3
# 0  0.711621  0.171995  0.067180  0.954159
# 1  0.062469  0.395537  0.301222  0.591743
# 2  0.510083  0.213392  0.187915  0.262417
# 3  0.420045  0.705421  0.583066  0.157629

# %%
#Task 2
columnName=['Random value 1','Random value 2','Random value 3','Random value 4']
df.columns=columnName
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.711621        0.171995        0.067180        0.954159
# 1        0.062469        0.395537        0.301222        0.591743
# 2        0.510083        0.213392        0.187915        0.262417
# 3        0.420045        0.705421        0.583066        0.157629

# %%
#Task 3
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.426054        0.371586        0.284846        0.491487
# std          0.271318        0.242818        0.220588        0.359653
# min          0.062469        0.171995        0.067180        0.157629
# 25%          0.330651        0.203043        0.157731        0.236220
# 50%          0.465064        0.304465        0.244569        0.427080
# 75%          0.560467        0.473008        0.371683        0.682347
# max          0.711621        0.705421        0.583066        0.954159

# %%
#Task 4
df.isnull().any().any() #to check if there is any null values in df
# Out:
# False

# %%
#Task 5
print("\nUsing label location\n",df.loc[:,'Random value 2':'Random value 3'],"\n")
print("Using index location\n",df.iloc[:,1:3])
# Out:
# Using label location
#     Random value 2  Random value 3
# 0        0.171995        0.067180
# 1        0.395537        0.301222
# 2        0.213392        0.187915
# 3        0.705421        0.583066
#
# Using index location
#     Random value 2  Random value 3
# 0        0.171995        0.067180
# 1        0.395537        0.301222
# 2        0.213392        0.187915
# 3        0.705421        0.583066
